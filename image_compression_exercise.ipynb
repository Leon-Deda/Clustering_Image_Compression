# %% [markdown]
# # Image Compression Using K-Means Clustering (Exercise Notebook)

# %% [markdown]
# ## Exercise Notebook Walkthrough

# %% [raw]
# * GOAL *
# In this exercise, you'll explore how K-Means clustering can be used to compress an image by reducing the number of unique colors.

# %% [markdown]
# ##  - Follow these steps to complete the exercise -

# %% [raw]
# 1. Introduction (Section 1):
#    * Understand the concept of image compression and how K-Means clustering applies to it.
#
# 2. Setup and Required Libraries (Section 2):
#    * Import the necessary libraries. If you don't have them installed, use pip install as indicated.
#
# 3. Load and Display the Image, EDA Analysis (Section 3):
#    * Load an image of your choice or use the given iamge and convert it to RGB format for correct visualization.
#    ** Your Task: Answer why converting from BGR to RGB is necessary.
#
# 4. Preprocess the Image (Section 4):
#    * Reshape the image into a 2D array of pixel values.
#
# 5. Apply K-Means Clustering (Section 5):
#    * Define the number of clusters (k) and fit the K-Means algorithm to the pixel data.
#    ** Your Task: Choose a value for k and complete the code to retrieve cluster labels.
#    *** Discussion: How does changing k affect compression and image quality?
#
# 6. Evaluation and Discussion (Section 6):
#    * Your Task: Reflect on the trade-offs of compression. What happens if k is too low or too high?
#
# 7.Elbow Method (Section 7):
#    * Find the optimal k value by plotting distortions for different cluster counts.
#    ** Your Task: Complete the code and interpret the elbow point.
#
# 8. Conclusion (Section 8):
#    * Summarize your findings. How effective was the compression? What were the limitations?
#
#
#
# **TIP**: Ensure that you run each section sequentially and provide thoughtful answers to the questions in the notebook.

# %% [markdown]
# ## 1. Introduction (Section 1)

# %% [raw]
# * What is Image Compression?
#
# Image compression is a technique used to reduce the size of an image file without significantly compromising its quality.
# This is achieved by reducing the number of unique colors in the image which can be efficiently stored and processed.

# %% [raw]
# * What is K-means clsutering?
#
# K-Means clustering is an unsupervised machine learning algorithm used to group similar data points into clusters.
#
# * In this approach:
# 1. Initialization: Choose k cluster centers (centroids) randomly.
# 2. Assignment: Assign each data point to the nearest centroid based on distance (usually Euclidean).
# 3. Update: Calculate new centroids by averaging the points in each cluster.
# 4. Repeat: Reassign points and update centroids until the centroids no longer change significantly.
#
# * In image compression, each pixel (with RGB values) is treated as a data point. K-Means groups similar colored pixels into k clusters and each pixel is replaced by its cluster’s centroid, reducing the number of unique colors while maintaining visual quality.

# %% [raw]
# *  Why Use K-Means Clustering for Image Compression?
#
# K-Means clustering is an unsupervised machine learning algorithm that groups similar data points into clusters.
#
# * In image compression:
#   1. Each pixel in the image is treated as a data point with three features (R, G, B values).
#   2. K-Means groups pixels with similar colors into "k" clusters.
#   3. Each pixel is then replaced by the centroid of its cluster, reducing the number of unique colors.

# %% [markdown]
# ## 2. Setup and Required Libraries (Section 2):

# %% [raw]
# **2. Required Libraries**
# Below are the required libraries for this practical. If not already installed, you can install them using this command in jupyter notebook cell:
#
# !pip install numpy matplotlib opencv-python scikit-learn

# %% [raw]
# * Before we begin working with image compression, we need to import some essential Python libraries. These libraries help us with numerical operations,   image processing, visualization, and machine learning tasks.
#
# * Import the following libraries:
#
# 1. NumPy: For handling arrays and numerical operations.
# 2. Matplotlib: To visualize images and plots.
# 3. OpenCV: For reading and processing images.
# 4. Scikit-Learn: To use the K-Means clustering algorithm.

# %%
# Your task: Import the required libraries.
import _____ as np        # Library for numerical operations
import _____ as plt       # Library for plotting
import _____ as cv2       # Library for image processing
from _____ import KMeans  # Import KMeans for clustering

# %% [raw]
# * To make sure our plots and images are clearly visible, we need to adjust the default size of the figures. This can be done using the plt.rcParams       setting in Matplotlib.
#
# * Your Task:
#   Set the default size of the displayed figures to 10 inches wide and 8 inches tall using the following format:
#   plt.rcParams['figure.figsize'] =(width, height)

# %%
# Complete
plt.rcParams['figure.figsize'] = (___, ___)

# %% [markdown]
# ## 3. Load and Display the Image, EDA Analysis (Section 3):

# %% [raw]
# **3. Load and Display the Image**
# Let's start by loading an image. Ensure that you have an image file (`image.jpg`) in your working directory. By 'pwd' command line we check our working directory where we have to put our image.

# %% [raw]
# * To compress an image, we first need to load it into our workspace. We'll use OpenCV (cv2) to read the image and Matplotlib (plt) to display it.
#
# * Your Task:
#
# Load an image using cv2.imread(). Make sure the image file is in your working directory.
# Convert the image from BGR (OpenCV’s default format) to RGB (used for proper color display).
# Display the image using plt.imshow().
#
# * Hint:
#
# OpenCV reads images in BGR format, but Matplotlib expects RGB.
# Use cv2.cvtColor(image, cv2.COLOR_BGR2RGB) to convert the color format.

# %%
# Load the image (replace '_____.jpg' with your image file name)
image = cv2.imread('____.jpg')

# Convert BGR to RGB for correct color display
image = cv2.cvtColor(image, cv2.____)

# Display the image
plt.imshow(____)
plt.axis("off")  # Hides axis for a cleaner display
plt.title("Original Image")
plt.show()

# %% [raw]
# *** Question: Why do you think OpenCV uses BGR by default, while most other libraries use RGB?

# %% [raw]
# Below you will find a short explenation of EDA analysis.
#
# * What is Exploratory Data Analysis (EDA)?
#
# Exploratory Data Analysis (EDA) is the process of analyzing and visualizing a dataset to understand its patterns, trends, and characteristics before applying machine learning or modeling. It involves:
#
# Summarizing data (e.g., checking shape, data types, missing values).
# Visualizing distributions (e.g., histograms, box plots, scatter plots).
# Detecting patterns & outliers (e.g., correlations, anomalies).
# For image processing, EDA includes displaying images, analyzing color distributions, checking unique colors, and visualizing pixel intensity histograms. It helps in making informed decisions before applying techniques like K-Means clustering for compression.

# %% [raw]
# * After loading the image, it's important to understand its structure. Each image has specific dimensions (height, width, and color channels) and a data type for storing pixel values.
#
# * Your Task:
#
# Check the image shape using the .shape attribute. This will show the height, width, and the number of color channels (RGB).
# Check the data type of the image using the .dtype attribute. This tells us how each pixel value is stored (usually as 8-bit integers ranging from 0 to 255).
#
# * Hint:
#
# An image shape might look like (800, 600, 3) — meaning 800 pixels height, 600 pixels width, and 3 channels (Red, Green, Blue).
# Common data types for images include uint8 (unsigned 8-bit integers).

# %%
# Check image dimensions and data type
print(f"Image Shape: {image._____}")  # Hint: Use the shape attribute
print(f"Data Type: {image._____}")    # Hint: Use the dtype attribute

# %% [raw]
# * To better understand the image, we'll examine how pixel values are distributed across the three color channels: Red, Green, and Blue.
#
# * Your Task:
#
# Split the image into its three color channels using cv2.split().
# Plot a histogram for each channel to visualize the pixel intensity distribution.
#
# * Hint:
#
# The cv2.split(image) function returns three separate arrays: one for red, one for green, and one for blue.
# Use plt.hist() to plot histograms, and ravel() to flatten each channel into a 1D array.

# %%
# Split the image into R, G, B channels
r, g, b = cv2.split(____)

# Plot the histograms for each channel
plt.figure(figsize=(____,____ ))  # Set the figure size (width, height)
plt.hist(r.ravel(), bins=256, color='___', alpha=0.6, label='Red')   # Set color for red channel
plt.hist(g.ravel(), bins=256, color='___', alpha=0.6, label='Green') # Set color for green channel
plt.hist(b.ravel(), bins=256, color='___', alpha=0.6, label='Blue')  # Set color for blue channel

plt.xlabel("Pixel Value")
plt.ylabel("Frequency")
plt.legend()
plt.title("Color Distribution in Image")
plt.show()

# %% [raw]
# * Before we apply image compression using K-Means, it's important to understand the number of unique colors in the image. By reducing the number of colors, we can effectively compress the image.
#
# * Your Task:
# Reshape the image: First, flatten the image into a 2D array where each row represents a single pixel with its RGB values.
# Count unique colors: Use a method to find all the unique color combinations (RGB values) in the image.
#
# * Why is this important?
#
# In the K-Means compression process, the algorithm reduces the number of unique colors in an image. Knowing how many unique colors exist helps us understand how much compression we can apply.

# %%
# Reshape the image to a 2D array (height * width, 3)
# This will flatten the image into a list of pixels
pixels = image._____  # Hint: Use reshape method to flatten the image

# Count unique colors in the image
# Use np.unique to find all unique rows (colors) in the pixels array
unique_colors = np._____  # Hint: Use np.unique to get unique rows

# Print the number of unique colors
print(f"Number of unique colors: {_____}")  # Hint: Use len() to find the count

# %% [markdown]
# ## 4. Preprocess the Image (Section 4):

# %% [raw]
# **4. Preprocessing the Image**
# We need to reshape the image into a 2D array, where each row represents a pixel with its RGB values.

# %%
# Reshape the image into a 2D array (height * width, 3).An image is typically a 3D NumPy array with the shape (height, width, 3) 
# where height represents the number of rows (pixels), width represents the number of columns (pixels)
# and 3 corresponds to the three color channels (Red, Green, Blue - RGB). Using .reshape(-1, 3), the image is flattened into a 2D array
# where -1 automatically calculates the number of rows as height × width (total pixels), and 3 preserves the three color channels. 
# For example, an image with dimensions (100, 100, 3) would be reshaped into (10000, 3), where each row represents a pixel with three values [R, G, B].
pixels = image.reshape(___, ____)

# Check the shape of the array. This checks the dimensions of the reshaped array to confirm that it has been converted into a 2D array of shape (num_pixels, 3).
print(f"Shape of pixel array: {pixels.shape}")

# %% [markdown]
# ## 5. Apply K-Means Clustering (Section 5):

# %% [raw]
# **5. Apply K-Means Clustering**
# We will now apply K-Means clustering with a defined number of clusters.
#
# ** Below you will find the code where we have applied k-means clustering using k = 4. Based on the code below, apply yourself k-means clustering when
# k is equal to 16. Try different k values and observe the changes in the image.

# %%
# Choose number of clusters (reduced colors)
k = 4  # You can experiment with different values

# Apply K-Means
kmeans = KMeans(n_clusters=k, random_state=42, n_init=10)
kmeans.fit(pixels)

# Get the cluster centers (new colors)
cluster_colors = kmeans.cluster_centers_

# Convert back to 8-bit values
cluster_colors = np.round(cluster_colors).astype(int)

print(f"Clustered Colors (New Color Palette with {k} colors):\n", cluster_colors)


# Get labels for each pixel
labels = kmeans.labels_

# Reconstruct the image using clustered colors
compressed_image = cluster_colors[labels]
compressed_image = compressed_image.reshape(image.shape)

# Display the compressed image
plt.figure(figsize=(6, 6))
plt.imshow(compressed_image)
plt.axis("off")
plt.title(f"Compressed Image with {k} Colors")
plt.show()

# %% [raw]
# * Observe the images with different k values and answer the following question:
#
# *How does changing k affect compression and image quality?
#
# * Your answer:

# %% [markdown]
# ## 6. Evaluation and Discussion (Section 6):

# %% [raw]
# * If you want to compare the two compressed image with the original one, you can try to build the code yourself.However it
# not mandatory to do it, but if you want to know how to build the code for that, you can find it in the solution notebook.
#
# * From what you understood so far, answer these two questions:
#
# 1. What are the limitations and Strengths of K-Means for Image Compression?
# 2. What happens if k is too low or too high?
#
# * Your answer:

# %% [markdown]
# ## 7.Elbow Method (Section 7):

# %% [raw]
# * What is Elbow method?
#
# The elbow method helps determine the optimal number of clusters (k) in K-Means by plotting the inertia (within-cluster sum of squares) against different values of k. The "elbow" point, where inertia stops decreasing significantly, suggests the best k for clustering.

# %% [raw]
# * In this challenge, we will use the Elbow Method to find the optimal value of k for K-Means clustering. The idea is to plot the distortion (also known as inertia) for a range of values of k and look for the "elbow" in the plot. The "elbow" corresponds to the point where increasing k no longer significantly improves the clustering, helping us choose the optimal value of k.
#
# * Your Task:
#
# Apply K-Means for different values of k: We'll try different values of k (from 1 to 16) and calculate the distortion for each.
# Plot the results: You will plot the distortion for each value of k and visually identify the "elbow."
#
# *What is Distortion?
#
# Distortion measures how well the clustering fits the data. It's calculated as the sum of squared distances between the data points and their assigned cluster centers. Lower distortion indicates better clustering.
#
# * How to identify the optimal k:
#
# Plot the Distortion: The graph will show distortion on the y-axis and k (number of clusters) on the x-axis.
# Find the "Elbow": The optimal k is typically where the plot first starts to flatten out or where the decrease in distortion slows down significantly.
# Interpretation: Before the elbow, increasing k significantly reduces distortion. After the elbow, adding more clusters doesn't reduce distortion much, so that's usually the point where you stop increasing k.
#
# Example:
# If the graph shows a sharp drop in distortion from k=1 to k=4 and then flattens out, then k=4 would likely be the optimal number of clusters.

# %%
# Implementing the Elbow Method
distortions = []
K_values = range(___, ___) # k values can range from 1 to large number, so choose your desired k number, however keep in mind that the larger the range is the better optimal k you will find, however longer it will take for the ouput to be processed.

for k in K_values:
    kmeans = KMeans(n_clusters=k, random_state=42, n_init=10)
    kmeans.fit(pixels)
    distortions.append(kmeans.inertia_)

plt.plot(K_values, distortions, marker='o')
plt.xlabel('Number of Clusters (k)')
plt.ylabel('Distortion')
plt.title('Elbow Method for Optimal k')
plt.show()

# %% [raw]
# * Question: From what you learnt, interpret the elbow point and find the optimal k from your k_values range.
#
# * Your answer:

# %% [markdown]
# ## 8. Conclusion (Section 8):

# %% [raw]
# * From what you learnt from this exercise book answer the following questions:
#
# 1. What is Image Compression using K-Means
# 2. How effective was the compression?
# 3. What were the limitations?
# 4. What is the Elbow Method for Identifying Optimal k?
#
# * Your answer:
